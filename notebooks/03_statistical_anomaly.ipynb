# %%
import pandas as pd
import numpy as np
import scipy
print(scipy.__version__)
print(scipy.__file__)
# Out:
# 1.18.0
# d:\Deep Learning\Anomaly Detection\anomaly\Lib\site-packages\scipy\__init__.py

# %%
df = pd.read_csv("D:/Deep Learning/Anomaly Detection/data/predictive_maintenance.csv")

# %%
from scipy.stats import zscore

df["torque_zscore"] = zscore(df["Torque [Nm]"])

df["torque_anomaly"] = (
    abs(df["torque_zscore"]) > 3
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from scipy.stats import zscore
#       2
#       3 df["torque_zscore"] = zscore(df["Torque [Nm]"])
#       4
#
# File d:\Deep Learning\Anomaly Detection\anomaly\Lib\site-packages\scipy\stats\__init__.py:600
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)    595
#     596 """  # noqa: E501
#     598 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     599                                DegenerateDataWarning, FitError)
# --> 600 from ._stats_py import *
#     601 from ._variation import variation
#     602 from .distributions import *
#
# File d:\Deep Learning\Anomaly Detection\anomaly\Lib\site-packages\scipy\stats\_stats_py.py:51
#      47 # Import unused here but needs to stay until end of deprecation periode
# ...
